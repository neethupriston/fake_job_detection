# %% [markdown]
# <a href="https://colab.research.google.com/github/neethupriston/fake_job_detection/blob/main/fake_job_posting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
#/content/drive/MyDrive/fake_job_postings.csv
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv("/content/drive/MyDrive/fake_job_postings.csv")
df
# Out:
#        job_id                                              title  \
# 0           1                                   Marketing Intern
# 1           2          Customer Service - Cloud Video Production
# 2           3            Commissioning Machinery Assistant (CMA)
# 3           4                  Account Executive - Washington DC
# 4           5                                Bill Review Manager
# ...       ...                                                ...
# 17875   17876                   Account Director - Distribution
# 17876   17877                                 Payroll Accountant
# 17877   17878  Project Cost Control Staff Engineer - Cost Con...
# 17878   17879                                   Graphic Designer
# 17879   17880                         Web Application Developers
#
#                    location   department salary_range  \
# 0          US, NY, New York    Marketing          NaN
# 1            NZ, , Auckland      Success          NaN
# ...

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

df['salary_range'] = df['salary_range'].str.replace('.*(Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec).*', 'Not Specified', regex=True)

# %%
df = df[df['department']!='Dev2 to 5 years experience in a client-facing technical role. Ability to diplomatically address customer concerns and provide feedback. A firm understanding of the technology stacks common to the Web ecosystem. A demonstrated history of creating non-trivi']

# %%
df['department'] = df['department'].replace(r'^\s*$', 'Not Specified', regex=True)
# Out:
# /tmp/ipykernel_532/1308912697.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['department'] = df['department'].replace(r'^\s*$', 'Not Specified', regex=True)

# %%
df.isnull().sum()
# Out:
# job_id                     0
# title                      0
# location                 346
# department             11547
# salary_range           15012
# company_profile         3308
# description                1
# requirements            2696
# benefits                7212
# telecommuting              0
# has_company_logo           0
# has_questions              0
# employment_type         3471
# required_experience     7050
# required_education      8105
# industry                4903
# function                6455
# fraudulent                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
round((df.isnull().sum()/df.shape[0])*100,2)
# Out:
# job_id                  0.00
# title                   0.00
# location                1.94
# department             64.58
# salary_range           83.96
# company_profile        18.50
# description             0.01
# requirements           15.08
# benefits               40.34
# telecommuting           0.00
# has_company_logo        0.00
# has_questions           0.00
# employment_type        19.41
# required_experience    39.43
# required_education     45.33
# industry               27.42
# function               36.10
# fraudulent              0.00
# dtype: float64

# %%
df = df.dropna(subset=['location'])

# %%
df[['employment_type', 'required_experience', 'required_education',
    'industry', 'function', 'department', 'company_profile',
    'requirements', 'benefits', 'description']] = df[['employment_type', 'required_experience', 'required_education',
    'industry', 'function', 'department', 'company_profile',
    'requirements', 'benefits', 'description']].fillna("Not Specified")

# %%
df['fraudulent'].value_counts()
# Out:
# fraudulent
# 0    16686
# 1      847
# Name: count, dtype: int64

# %%
df['fraudulent'].shape
# Out:
# (17533,)

# %%
df['salary_range']= df['salary_range'].fillna(" ")

# %%
round((df.isnull().sum()/df.shape[0])*100,2)
# Out:
# job_id                 0.0
# title                  0.0
# location               0.0
# department             0.0
# salary_range           0.0
# company_profile        0.0
# description            0.0
# requirements           0.0
# benefits               0.0
# telecommuting          0.0
# has_company_logo       0.0
# has_questions          0.0
# employment_type        0.0
# required_experience    0.0
# required_education     0.0
# industry               0.0
# function               0.0
# fraudulent             0.0
# dtype: float64

# %%
cate_salary = df['salary_range'].value_counts()
cate_salary.to_csv('salary.csv')

# %%
salary_ran = []
for index, row in df.iterrows():


   if ("-" not in str(row['salary_range'])) and (" " not in str(row['salary_range'])) :
       salary_ran.append(index)
print(salary_ran)
# Out:
# [5538]

# %%
df.drop(5538,inplace =True)

# %%
df[['min_salary', 'max_salary']] = df['salary_range'].str.split('-', expand=True)

# %%
print(df['min_salary'].dtype)
# Out:
# object

# %%
df['min_salary'].fillna(" ", inplace=True)
df['max_salary'].fillna(" ", inplace=True)
# Out:
# /tmp/ipykernel_532/1340820994.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['min_salary'].fillna(" ", inplace=True)
# /tmp/ipykernel_532/1340820994.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df['min_salary']=pd.to_numeric(df['min_salary'],errors='coerce')
df['min_salary'].to_csv('min_salary.csv')
print(df['min_salary'].dtype)
# Out:
# float64

# %%
df['max_salary']=pd.to_numeric(df['max_salary'],errors='coerce')
df['max_salary'].to_csv('max_salary.csv')
print(df['max_salary'].dtype)
# Out:
# float64

# %%
from sklearn.model_selection import train_test_split
X_fake_job = df.drop(['fraudulent'],axis=1)
y_fake_job = df['fraudulent']
X_train_fake_job,X_test_fake_job,y_train_fake_job,y_test_fake_job = train_test_split(X_fake_job,y_fake_job,test_size=0.2)
print(y_test_fake_job.shape)
print(X_train_fake_job.shape)
# Out:
# (3507,)
# (14025, 19)

# %%
#pip install transformers

# %%
#pip install torch

# %%
df.columns
# Out:
# Index(['job_id', 'title', 'location', 'department', 'salary_range',
#        'company_profile', 'description', 'requirements', 'benefits',
#        'telecommuting', 'has_company_logo', 'has_questions', 'employment_type',
#        'required_experience', 'required_education', 'industry', 'function',
#        'fraudulent', 'min_salary', 'max_salary'],
#       dtype='object')

# %%
from transformers import RobertaTokenizer
import os
os.environ["HF_TOKEN"] = "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"
tokenizer = RobertaTokenizer.from_pretrained("roberta-base")
encoded_batch_description = tokenizer(
    X_train_fake_job['description'].astype(str).tolist(), # Added .astype(str) here
    padding=True,
    truncation=True,
    max_length=512,
    return_tensors="pt"
)
encoded_batch_description_test = tokenizer(
    X_test_fake_job['description'].astype(str).tolist(), # Added .astype(str) here
    padding=True,
    truncation=True,
    max_length=512,
    return_tensors="pt"
)
print("Shape of Input IDs:", encoded_batch_description['input_ids'].shape)
print("Shape of Attention Mask:", encoded_batch_description['attention_mask'].shape)
first_decoded_text = tokenizer.decode(encoded_batch_description['input_ids'][0], skip_special_tokens=True)
second_decoded_text = tokenizer.decode(encoded_batch_description['input_ids'][1], skip_special_tokens=True)
third_decoded_text = tokenizer.decode(encoded_batch_description['input_ids'][2], skip_special_tokens=True)
print("\nFirst Decoded Text:", first_decoded_text,"\n\n")
print("\nsecond Decoded Text:", second_decoded_text,"\n\n")
print("\nthird Decoded Text:", third_decoded_text,"\n\n")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Shape of Input IDs: torch.Size([14025, 512])
# Shape of Attention Mask: torch.Size([14025, 512])
#
# ...

# %%
requirements_encoded_batch = tokenizer(
    X_train_fake_job['requirements'].tolist(),
    padding=True,
    truncation=True,
    max_length=512,
    return_tensors="pt"
)
requirements_encoded_batch_test = tokenizer(
    X_test_fake_job['requirements'].tolist(),
    padding=True,
    truncation=True,
    max_length=512,
    return_tensors="pt"
)
print("Shape of Input IDs:", requirements_encoded_batch['input_ids'].shape)
print("Shape of Attention Mask:", requirements_encoded_batch['attention_mask'].shape)
print("Shape of Input IDs:", requirements_encoded_batch_test['input_ids'].shape)
print("Shape of Attention Mask:", requirements_encoded_batch_test['attention_mask'].shape)
requirements_first_decoded_text = tokenizer.decode(requirements_encoded_batch['input_ids'][0], skip_special_tokens=True)
print("\nFirst Decoded Text:", requirements_first_decoded_text)
requirements_second_decoded_text = tokenizer.decode(requirements_encoded_batch['input_ids'][567], skip_special_tokens=True)
print("\nFirst Decoded Text:", requirements_second_decoded_text)
requirements_third_decoded_text = tokenizer.decode(requirements_encoded_batch['input_ids'][678], skip_special_tokens=True)
print("\nFirst Decoded Text:", requirements_third_decoded_text)
# Out:
# Shape of Input IDs: torch.Size([14025, 512])
# Shape of Attention Mask: torch.Size([14025, 512])
# Shape of Input IDs: torch.Size([3507, 512])
# Shape of Attention Mask: torch.Size([3507, 512])
#
# First Decoded Text: Bachelor’s degree or equivalent experienceAn understanding of user-centered design principles and the technical skills to implement themExperience with 3D modeling packages (Blender, Renderman, 3Ds Max, etc.)
#
# First Decoded Text: Not Specified
#
# ...

# %%
title_encoded_batch = tokenizer(
    X_train_fake_job['title'].tolist(),
    padding=True,
    truncation=True,
    max_length=512,
    return_tensors="pt"
)
title_encoded_batch_test = tokenizer(
    X_test_fake_job['title'].tolist(),
    padding=True,
    truncation=True,
    max_length=512,
    return_tensors="pt"
)
print("Shape of Input IDs:", title_encoded_batch['input_ids'].shape)
print("Shape of Attention Mask:", title_encoded_batch['attention_mask'].shape)
title_first_decoded_text = tokenizer.decode(title_encoded_batch['input_ids'][0], skip_special_tokens=True)
print("\nFirst Decoded Text:",title_first_decoded_text)
title_first_decoded_text = tokenizer.decode(title_encoded_batch['input_ids'][16], skip_special_tokens=True)
print("\nFirst Decoded Text:",title_first_decoded_text)
title_first_decoded_text = tokenizer.decode(title_encoded_batch['input_ids'][367], skip_special_tokens=True)
print("\nFirst Decoded Text:",title_first_decoded_text)
# Out:
# Shape of Input IDs: torch.Size([14025, 39])
# Shape of Attention Mask: torch.Size([14025, 39])
#
# First Decoded Text: UI/UX Developer
#
# First Decoded Text: GIS Mapping Engineer
#
# First Decoded Text: Accountant

# %%
benefits_encoded_batch = tokenizer(
    X_train_fake_job['benefits'].tolist(),
    padding=True,
    truncation=True,
    max_length=512,
    return_tensors="pt"
)
benefits_encoded_batch_test = tokenizer(
    X_test_fake_job['benefits'].tolist(),
    padding=True,
    truncation=True,
    max_length=512,
    return_tensors="pt"
)
print("Shape of Input IDs:", benefits_encoded_batch['input_ids'].shape)
print("Shape of Attention Mask:", benefits_encoded_batch['attention_mask'].shape)
benefits_first_decoded_text = tokenizer.decode(benefits_encoded_batch['input_ids'][0], skip_special_tokens=True)
print("\nFirst Decoded Text:",benefits_first_decoded_text)
# Out:
# Shape of Input IDs: torch.Size([14025, 512])
# Shape of Attention Mask: torch.Size([14025, 512])
#
# First Decoded Text: You’ll receive a competitive salary and stock options as well as great benefits like unlimited vacation, flexible hours, gourmet coffee and weekly happy hours (happiness is voluntary at these events, but it’s strongly encouraged by plentiful beer).

# %%
company_profile_encoded_batch = tokenizer(
    X_train_fake_job['company_profile'].tolist(),
    padding=True,
    truncation=True,
    max_length=512,
    return_tensors="pt"
)
company_profile_encoded_batch_test = tokenizer(
    X_test_fake_job['company_profile'].tolist(),
    padding=True,
    truncation=True,
    max_length=512,
    return_tensors="pt"
)
print("Shape of Input IDs:", company_profile_encoded_batch['input_ids'].shape)
print("Shape of Attention Mask:", company_profile_encoded_batch['attention_mask'].shape)
company_profile_first_decoded_text = tokenizer.decode(company_profile_encoded_batch['input_ids'][0], skip_special_tokens=True)
print("\nFirst Decoded Text:",company_profile_first_decoded_text)
# Out:
# Shape of Input IDs: torch.Size([14025, 512])
# Shape of Attention Mask: torch.Size([14025, 512])
#
# First Decoded Text: Floored is a New York City–based company that creates interactive 3d graphics for commercial, residential, industrial, &amp; retail real estate, and the hospitality industry.

# %%
department_encoded_batch = tokenizer(
    X_train_fake_job['department'].astype(str).tolist(),
    padding=True,
    truncation=True,
    max_length=512,
    return_tensors="pt"
)
department_encoded_batch_test = tokenizer(
    X_test_fake_job['department'].astype(str).tolist(),
    padding=True,
    truncation=True,
    max_length=512,
    return_tensors="pt"
)
print("Shape of Input IDs:", department_encoded_batch['input_ids'].shape)
print("Shape of Attention Mask:", department_encoded_batch['attention_mask'].shape)
department_first_decoded_text = tokenizer.decode(department_encoded_batch['input_ids'][4], skip_special_tokens=True)
print("\nFirst Decoded Text:",department_first_decoded_text)
# Out:
# Shape of Input IDs: torch.Size([14025, 24])
# Shape of Attention Mask: torch.Size([14025, 24])
#
# First Decoded Text: Not Specified

# %%
location_encoded_batch_train = tokenizer(
    X_train_fake_job['location'].tolist(),
    padding=True,
    truncation=True,
    max_length=512,
    return_tensors="pt"
)
location_encoded_batch_test = tokenizer(
    X_test_fake_job['location'].tolist(),
    padding=True,
    truncation=True,
    max_length=512,
    return_tensors="pt"
)
print("Shape of Input IDs:", location_encoded_batch_train['input_ids'].shape)
print("Shape of Attention Mask:", location_encoded_batch_train['attention_mask'].shape)
location_first_decoded_text = tokenizer.decode(location_encoded_batch_train['input_ids'][0], skip_special_tokens=True)
print("\nFirst Decoded Text:",location_first_decoded_text)
# Out:
# Shape of Input IDs: torch.Size([14025, 93])
# Shape of Attention Mask: torch.Size([14025, 93])
#
# First Decoded Text: US, NY, New York

# %%
cate_ind = df['industry'].value_counts()
cate_ind.to_csv('industry.csv')

# %%
df.columns
# Out:
# Index(['job_id', 'title', 'location', 'department', 'salary_range',
#        'company_profile', 'description', 'requirements', 'benefits',
#        'telecommuting', 'has_company_logo', 'has_questions', 'employment_type',
#        'required_experience', 'required_education', 'industry', 'function',
#        'fraudulent', 'min_salary', 'max_salary'],
#       dtype='object')

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip



# Unzip the downloaded file

# !unzip -n glove.6B.zip
# Out:
# --2026-05-07 13:26:22--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2026-05-07 13:26:22--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2026-05-07 13:26:23--  https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# ...

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 99.2 MB/s eta 0:00:00
# ...

# %%
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec

raw_glove_file = 'glove.6B.100d.txt'
word2vec_file = 'glove.6B.100d.word2vec.txt'

# %%
# Check if the converted Word2Vec file already exists
if not os.path.exists(word2vec_file):
    print(f"'{word2vec_file}' not found. Checking for the raw '{raw_glove_file}'...")

    # If the raw file exists, convert it
    if os.path.exists(raw_glove_file):
        print("Raw file found! Converting to Word2Vec format (this may take a minute)...")
        glove2word2vec(raw_glove_file, word2vec_file)
        print("Conversion complete!")
    else:
        # If neither file exists, stop the code and warn the user
        raise FileNotFoundError(f"Missing File! Please upload '{raw_glove_file}' to your current folder.")

# Load the model into memory

glove_model = KeyedVectors.load_word2vec_format(word2vec_file)


# ==========================================
# STEP 3: CATEGORIZE & ENCODE
# ==========================================
# Extract unique categories (ignoring missing/NaN values)
unique_categories_train = X_train_fake_job['industry'].unique()
print(f"Found {len(unique_categories_train)} unique categories to encode.")

def get_mean_glove_vector(text, model):
    """Splits a category name into words and averages their GloVe vectors."""
    words = str(text).lower().split()
    vectors = [model[w] for w in words if w in model]
    #print(model.vector_size)
    if not vectors:
        return np.zeros(model.vector_size) # Return array of zeros if no words match

    return np.mean(vectors, axis=0)


# Create a dictionary mapping: { 'Industry Name' : [Vector Array] }
category_to_vector = {cat: get_mean_glove_vector(cat, glove_model) for cat in unique_categories_train}


# ==========================================
# STEP 4: MAP BACK TO MAIN DATAFRAME
# ==========================================
# Map the vectors back to the original dataset based on the industry name
X_train_fake_job['industry_map'] = X_train_fake_job['industry'].map(category_to_vector)

print("\n--- Final Dataset Preview ---")
print(type(X_train_fake_job['industry_map']))
#print(df[['industry', 'industry_embedded']].head())
# Out:
# 'glove.6B.100d.word2vec.txt' not found. Checking for the raw 'glove.6B.100d.txt'...
# Raw file found! Converting to Word2Vec format (this may take a minute)...
# /tmp/ipykernel_647/263958751.py:8: DeprecationWarning: Call to deprecated `glove2word2vec` (KeyedVectors.load_word2vec_format(.., binary=False, no_header=True) loads GLoVE text vectors.).
#   glove2word2vec(raw_glove_file, word2vec_file)
# Conversion complete!
# Found 131 unique categories to encode.
#
# --- Final Dataset Preview ---
# <class 'pandas.core.series.Series'>

# %%
unique_categories_test = X_test_fake_job['industry'].unique()
print(f"Found {len(unique_categories_test)} unique categories to encode.")

category_to_vector = {cat: get_mean_glove_vector(cat, glove_model) for cat in unique_categories_test}

X_test_fake_job['industry_map'] = X_test_fake_job['industry'].map(category_to_vector)

print("\n--- Final Dataset Preview ---")
print(X_test_fake_job['industry_map'].shape)
# Out:
# Found 114 unique categories to encode.
#
# --- Final Dataset Preview ---
# (3507,)

# %%
df['employment_type'].value_counts()
# Out:
# employment_type
# Full-time        11522
# Not Specified     3257
# Contract          1512
# Part-time          783
# Temporary          239
# Other              219
# Name: count, dtype: int64

# %%
unique_categories_train_employment = X_train_fake_job['employment_type'].unique()
print(f"Found {len(unique_categories_train_employment)} unique categories to encode.")

category_to_vector_employment_type_train = {cat: get_mean_glove_vector(cat, glove_model) for cat in unique_categories_train_employment}

X_train_fake_job['employment_type_encoded'] = X_train_fake_job['employment_type'].map(category_to_vector_employment_type_train)

print("\n--- Final Dataset Preview ---")
print(X_train_fake_job['employment_type_encoded'].shape)
# Out:
# Found 6 unique categories to encode.
#
# --- Final Dataset Preview ---
# (14025,)

# %%
# 1. Extract unique categories for employment_type
unique_categories_test_employment_type = X_test_fake_job['employment_type'].unique()
print(f"Found {len(unique_categories_test_employment_type)} unique categories to encode.")

# 2. Create a mapping dictionary using the GloVe model
category_to_vector_employment_type_test = {
    cat: get_mean_glove_vector(cat, glove_model)
    for cat in unique_categories_test_employment_type
}

# 3. Map the categories to their respective vectors
X_test_fake_job['employment_type_encoded'] = X_test_fake_job['employment_type'].map(category_to_vector_employment_type_test)

print("\n--- Final Dataset Preview ---")
# This will show the number of rows and confirm the encoding
print(f"Encoded shape: {X_test_fake_job['employment_type_encoded'].shape}")
# Out:
# Found 6 unique categories to encode.
#
# --- Final Dataset Preview ---
# Encoded shape: (3507,)

# %%
print(df['required_experience'].value_counts())
# Out:
# required_experience
# Not Specified       6797
# Mid-Senior level    3776
# Entry level         2685
# Associate           2280
# Not Applicable      1100
# Director             386
# Internship           368
# Executive            140
# Name: count, dtype: int64

# %%
unique_categories_train_required_experience = X_train_fake_job['required_experience'].unique()
print(f"Found {len(unique_categories_train_required_experience)} unique categories to encode.")

category_to_vector_required_experience_train = {cat: get_mean_glove_vector(cat, glove_model) for cat in unique_categories_train_required_experience}

X_train_fake_job['required_experience_encoded'] = X_train_fake_job['required_experience'].map(category_to_vector_required_experience_train)

print("\n--- Final Dataset Preview ---")
print(X_train_fake_job['required_experience_encoded'].shape)
# Out:
# Found 8 unique categories to encode.
#
# --- Final Dataset Preview ---
# (14025,)

# %%
unique_categories_test_required_experience = X_test_fake_job['required_experience'].unique()
print(f"Found {len(unique_categories_test_required_experience)} unique categories to encode.")

category_to_vector_required_experience_test = {cat: get_mean_glove_vector(cat, glove_model) for cat in unique_categories_test_required_experience}

X_test_fake_job['required_experience_encoded'] = X_test_fake_job['required_experience'].map(category_to_vector_required_experience_test)

print("\n--- Final Dataset Preview ---")
print(X_test_fake_job['required_experience_encoded'].shape)
# Out:
# Found 8 unique categories to encode.
#
# --- Final Dataset Preview ---
# (3507,)

# %%
print(df['required_education'].value_counts())
# Out:
# required_education
# Not Specified                        7821
# Bachelor's Degree                    5110
# High School or equivalent            2067
# Unspecified                          1392
# Master's Degree                       410
# Associate Degree                      272
# Certification                         169
# Some College Coursework Completed     101
# Professional                           74
# Vocational                             48
# Some High School Coursework            27
# Doctorate                              26
# Vocational - HS Diploma                 9
# Vocational - Degree                     6
# Name: count, dtype: int64

# %%
# 1. Get unique categories for required_education
unique_categories_train_required_education = X_train_fake_job['required_education'].unique()
print(f"Found {len(unique_categories_train_required_education)} unique categories to encode.")

# 2. Create the mapping dictionary using GloVe vectors
category_to_vector_required_education_train = {
    cat: get_mean_glove_vector(cat, glove_model)
    for cat in unique_categories_train_required_education
}

# 3. Map the vectors to a new column
X_train_fake_job['required_education_encoded'] = X_train_fake_job['required_education'].map(category_to_vector_required_education_train)

# 4. Final Preview
print("\n--- Final Dataset Preview ---")
print(X_train_fake_job['required_education_encoded'].shape)
# Out:
# Found 14 unique categories to encode.
#
# --- Final Dataset Preview ---
# (14025,)

# %%
unique_categories_test_required_education = X_test_fake_job['required_education'].unique()
print(f"Found {len(unique_categories_test_required_education)} unique categories to encode.")


category_to_vector_required_education_test = {
    cat: get_mean_glove_vector(cat, glove_model)
    for cat in unique_categories_test_required_education
}


X_test_fake_job['required_education_encoded'] = X_test_fake_job['required_education'].map(category_to_vector_required_education_test)


print("\n--- Final Dataset Preview ---")
print(X_test_fake_job['required_education_encoded'].shape)
# Out:
# Found 14 unique categories to encode.
#
# --- Final Dataset Preview ---
# (3507,)

# %%
# 1. Get unique categories for required_education
unique_categories_train_function = X_train_fake_job['function'].unique()
print(f"Found {len(unique_categories_train_function)} unique categories to encode.")

# 2. Create the mapping dictionary using GloVe vectors
category_to_vector_function_train = {
    cat: get_mean_glove_vector(cat, glove_model)
    for cat in unique_categories_train_function
}

# 3. Map the vectors to a new column
X_train_fake_job['function_encoded'] = X_train_fake_job['function'].map(category_to_vector_function_train)

# 4. Final Preview
print("\n--- Final Dataset Preview ---")
print(X_train_fake_job['function_encoded'].shape)
# Out:
# Found 38 unique categories to encode.
#
# --- Final Dataset Preview ---
# (14025,)

# %%
unique_categories_test_function = X_test_fake_job['function'].unique()
print(f"Found {len(unique_categories_test_function)} unique categories to encode.")


category_to_vector_function_test = {
    cat: get_mean_glove_vector(cat, glove_model)
    for cat in unique_categories_test_function
}


X_test_fake_job['function_encoded'] = X_test_fake_job['function'].map(category_to_vector_function_test)


print("\n--- Final Dataset Preview ---")
print(X_test_fake_job['function_encoded'].shape)
# Out:
# Found 38 unique categories to encode.
#
# --- Final Dataset Preview ---
# (3507,)

# %%
X_train_fake_job.columns
# Out:
# Index(['job_id', 'title', 'location', 'department', 'salary_range',
#        'company_profile', 'description', 'requirements', 'benefits',
#        'telecommuting', 'has_company_logo', 'has_questions', 'employment_type',
#        'required_experience', 'required_education', 'industry', 'function',
#        'min_salary', 'max_salary', 'industry_map', 'employment_type_encoded',
#        'required_experience_encoded', 'required_education_encoded',
#        'function_encoded'],
#       dtype='object')

# %%
from sklearn.preprocessing import RobustScaler

salary_scaler = RobustScaler()

# Fit on BOTH columns together
train_salary_scaled = salary_scaler.fit_transform(
    X_train_fake_job[['min_salary', 'max_salary']]
)

# Transform test data using SAME scaler
test_salary_scaled = salary_scaler.transform(
    X_test_fake_job[['min_salary', 'max_salary']]
)
#X_train_fake_job = X_train_fake_job.drop(['min_salary_scaled','max_salary_scaled'],axis=1)
#X_test_fake_job = X_test_fake_job.drop(['min_salary_scaled','max_salary_scaled'],axis=1)
# Optional: split back into separate arrays

#min_salary_scaled_train = train_salary_scaled[:, 0]
#max_salary_scaled_train = train_salary_scaled[:, 1]

#min_salary_scaled_test = test_salary_scaled[:, 0]
#max_salary_scaled_test = test_salary_scaled[:, 1]

salary_train = pd.DataFrame(train_salary_scaled,columns=('min_salary_scaled','max_salary_scaled'))
salary_test =pd.DataFrame(test_salary_scaled,columns=('min_salary_scaled','max_salary_scaled'))

salary_train['max_salary_scaled'] = pd.to_numeric(salary_train['max_salary_scaled'] , errors='coerce')
salary_train['min_salary_scaled'] = pd.to_numeric(salary_train['min_salary_scaled'] , errors='coerce')
salary_test['max_salary_scaled'] = pd.to_numeric(salary_test['max_salary_scaled'] , errors='coerce')
salary_test['min_salary_scaled'] = pd.to_numeric(salary_test['min_salary_scaled'] , errors='coerce')

#salary_train.fillna("",inplace=True)
#salary_test.fillna("",inplace=True)
salary_train['max_salary_scaled'].head()
X_train_fake_job =pd.concat([X_train_fake_job,salary_train],axis=1)
X_test_fake_job = pd.concat([X_test_fake_job,salary_test],axis=1)
X_train_fake_job.columns
# Out:
# Index(['job_id', 'title', 'location', 'department', 'salary_range',
#        'company_profile', 'description', 'requirements', 'benefits',
#        'telecommuting', 'has_company_logo', 'has_questions', 'employment_type',
#        'required_experience', 'required_education', 'industry', 'function',
#        'min_salary', 'max_salary', 'min_salary_scaled', 'max_salary_scaled'],
#       dtype='object')

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import RobertaModel
from torch.optim import AdamW
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tqdm import tqdm # For progress bars
import numpy as np
print("Is CUDA available?:", torch.cuda.is_available())
# Out:
# Is CUDA available?: True

# %%
# ==========================================
# 1. DATASET CLASS
# ==========================================
class JobFraudDataset(Dataset):
    def __init__(self, roberta_ids, roberta_masks, glove_data,remaininput_data,numeric_data, labels):
        self.roberta_ids = roberta_ids
        self.roberta_masks = roberta_masks
        self.glove_data = glove_data
        self.numeric_data = numeric_data
        self.labels = labels
        self.remaininput_data = remaininput_data
    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return {
            'roberta_ids': self.roberta_ids[idx].clone().detach().long(),
            'roberta_mask': self.roberta_masks[idx].clone().detach().long(),
            # Convert the already embedded GloVe vectors directly to float32
            'glove_data': torch.tensor(self.glove_data[idx], dtype=torch.float32),
            'numeric_data': torch.tensor(self.numeric_data[idx], dtype=torch.float32),
             'remaininput_data': torch.tensor(self.remaininput_data[idx],dtype=torch.float32),
            'label': torch.tensor(self.labels[idx], dtype=torch.long)

            }

# ==========================================
# 2. THE HYBRID MODEL
# ==========================================
class UltimateJobFraudClassifier(nn.Module):
    def __init__(self, vocab_size, glove_dim, lstm_hidden, num_numeric_features, num_classes):
        super(UltimateJobFraudClassifier, self).__init__()



        # NO EMBEDDING LAYER: glove_data is already embedded (float vectors)
        # We pass it directly to the LSTM
        self.bi_lstm = nn.LSTM(input_size=glove_dim, hidden_size=lstm_hidden, batch_first=True, bidirectional=True)

        self.numeric_branch = nn.Sequential(
            nn.Linear(num_numeric_features, 16),
            nn.ReLU()
        )

        combined_dim = 768 + (lstm_hidden * 2) + 16
        self.classifier = nn.Sequential(
            nn.Linear(combined_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(256,64),
            nn.ReLU(),
            nn.Linear(64, num_classes)
        )

    def forward(self, roberta_ids, roberta_mask, glove_data, numeric_data,remaininput_data):
        roberta_features = self.roberta(input_ids=roberta_ids, attention_mask=roberta_mask).pooler_output

        # Pass glove_data directly to LSTM
        lstm_out, (hn, _) = self.bi_lstm(glove_data)
        glove_features = torch.cat((hn[-2, :, :], hn[-1, :, :]), dim=1)

        combined_numeric = torch.cat((numeric_data, remaininput_data), dim=1)
        numeric_features = self.numeric_branch(combined_numeric)

        final_combined = torch.cat((roberta_features, glove_features, numeric_features), dim=1)
        return self.classifier(final_combined)

# ==========================================
# 3. DATA PREPARATION (Combining Tensors)
# ==========================================
print("Combining Data...")

print("Properly Stacking GloVe Vectors...")

glove_cols = [
    'industry_map',
    'employment_type_encoded',
    'required_experience_encoded',
    'required_education_encoded',
    'function_encoded'
]

# 1. Function to ensure every item is exactly 100 numbers long
GLOVE_DIM = 100 # Based on your error, your GloVe vectors are 100D

def fix_glove_vector(vec):
    # If it is a valid vector of 100 numbers, keep it
    if isinstance(vec, (list, np.ndarray)) and len(vec) == GLOVE_DIM:
        return np.array(vec, dtype=np.float32)
    # If it is a single number, missing, or broken, return 100 zeros
    else:
        return np.zeros(GLOVE_DIM, dtype=np.float32)

# 2. Apply the fix to all your GloVe columns in Train and Test data
for col in glove_cols:
    X_train_fake_job[col] = X_train_fake_job[col].apply(fix_glove_vector)
    X_test_fake_job[col] = X_test_fake_job[col].apply(fix_glove_vector)

# 3. Now stack them safely! Every vector is guaranteed to be size 100.
X_train_glove = np.array([np.vstack(row) for row in X_train_fake_job[glove_cols].values], dtype=np.float32)
X_test_glove = np.array([np.vstack(row) for row in X_test_fake_job[glove_cols].values], dtype=np.float32)

print(f"Train GloVe Shape: {X_train_glove.shape}") # Should successfully print (Number_of_Jobs, 5, 100)


# Combine Train RoBERTa Data (Max 512 tokens)
X_train_roberta_ids = torch.cat((
    title_encoded_batch['input_ids'], company_profile_encoded_batch['input_ids'],
    encoded_batch_description['input_ids'], requirements_encoded_batch['input_ids'],
    benefits_encoded_batch['input_ids'], department_encoded_batch['input_ids'],
    location_encoded_batch_train['input_ids']
), dim=1)[:, :512]

X_train_roberta_masks = torch.cat((
    title_encoded_batch['attention_mask'], company_profile_encoded_batch['attention_mask'],
    encoded_batch_description['attention_mask'], requirements_encoded_batch['attention_mask'],
    benefits_encoded_batch['attention_mask'], department_encoded_batch['attention_mask'],
    location_encoded_batch_train['attention_mask']
), dim=1)[:, :512]

# Combine Test RoBERTa Data (Max 512 tokens) - Fixed the attention_mask typo here!
X_test_roberta_ids = torch.cat((
    title_encoded_batch_test['input_ids'], company_profile_encoded_batch_test['input_ids'],
    encoded_batch_description_test['input_ids'], requirements_encoded_batch_test['input_ids'],
    benefits_encoded_batch_test['input_ids'], department_encoded_batch_test['input_ids'],
    location_encoded_batch_test['input_ids']
), dim=1)[:, :512]

X_test_roberta_masks = torch.cat((
    title_encoded_batch_test['attention_mask'], company_profile_encoded_batch_test['attention_mask'],
    encoded_batch_description_test['attention_mask'], requirements_encoded_batch_test['attention_mask'],
    benefits_encoded_batch_test['attention_mask'], department_encoded_batch_test['attention_mask'],
    location_encoded_batch_test['attention_mask']
), dim=1)[:, :512]
X_train_scaled = X_train_fake_job[['min_salary_scaled', 'max_salary_scaled']].values
X_test_scaled = X_test_fake_job[['min_salary_scaled', 'max_salary_scaled']].values
X_train_datar = X_train_fake_job[['telecommuting', 'has_company_logo', 'has_questions']].values
X_test_datar = X_test_fake_job[['telecommuting', 'has_company_logo', 'has_questions']].values
X_train_scaled = np.nan_to_num(np.array(X_train_scaled, dtype=np.float32))
X_test_scaled = np.nan_to_num(np.array(X_test_scaled, dtype=np.float32))
X_train_datar = np.nan_to_num(np.array(X_train_datar, dtype=np.float32))
X_test_datar = np.nan_to_num(np.array(X_test_datar, dtype=np.float32))

# Create DataLoaders
train_dataset = JobFraudDataset(X_train_roberta_ids, X_train_roberta_masks, X_train_glove,X_train_datar, X_train_scaled, y_train_fake_job.values)
test_dataset = JobFraudDataset(X_test_roberta_ids, X_test_roberta_masks, X_test_glove,X_test_datar, X_test_scaled, y_test_fake_job.values)


train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True,num_workers=4)
test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False,num_workers=4)

# ==========================================
# 4. TRAINING SETUP
# ==========================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model = UltimateJobFraudClassifier(
    vocab_size=10000, glove_dim=100, lstm_hidden=128, num_numeric_features=5, num_classes=2).to(device)

# Handling Imbalance (1:19 ratio for 95% Real, 5% Fake)
class_weights = torch.tensor([5.0,15.0]).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights)

# Optimizer (AdamW is best for RoBERTa)
optimizer = AdamW(model.parameters(), lr=2e-5) # Very small learning rate for Transformers

# ==========================================
# 5. THE TRAINING LOOP
# ==========================================
EPOCHS = 5


scaler = torch.cuda.amp.GradScaler()

print("\n--- Starting Training ---")
for epoch in range(EPOCHS):
    model.train() # Set model to training mode
    total_loss = 0

    # tqdm adds a progress bar
    progress_bar = tqdm(train_dataloader, desc=f"Epoch {epoch+1}/{EPOCHS}")

    for batch in progress_bar:
        # Move data to GPU/CPU
        b_roberta_ids = batch['roberta_ids'].to(device)
        b_roberta_mask = batch['roberta_mask'].to(device)
        b_glove = batch['glove_data'].to(device)
        b_numeric = batch['numeric_data'].to(device)
        b_remaininput = batch['remaininput_data'].to(device)
        b_labels = batch['label'].to(device)

        # 1. Clear previous gradients
        optimizer.zero_grad()


        with torch.cuda.amp.autocast():
            outputs = model(b_roberta_ids, b_roberta_mask, b_glove, b_numeric, b_remaininput)
            loss = criterion(outputs, b_labels)

        total_loss += loss.item()


        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        progress_bar.set_postfix({'Loss': f"{loss.item():.4f}"})

    avg_train_loss = total_loss / len(train_dataloader)
    print(f"\nAverage Training Loss for Epoch {epoch+1}: {avg_train_loss:.4f}\n")
# ==========================================
# 6. EVALUATION / PREDICTION LOOP
# ==========================================
print("\n--- Starting Evaluation on Test Data ---")
model.eval() # Set model to evaluation mode
all_preds, all_labels = [], []

with torch.no_grad():
    for batch in tqdm(test_dataloader, desc="Predicting"):
        b_roberta_ids = batch['roberta_ids'].to(device)
        b_roberta_mask = batch['roberta_mask'].to(device)
        b_glove = batch['glove_data'].to(device)
        b_numeric = batch['numeric_data'].to(device)
        b_remaininput = batch['remaininput_data'].to(device)
        b_labels = batch['label'].to(device)

        outputs = model(b_roberta_ids, b_roberta_mask, b_glove, b_numeric,b_remaininput)
        preds = torch.argmax(outputs, dim=1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(b_labels.cpu().numpy())

print("\n=== FINAL RESULTS ===")
print(f"Overall Accuracy: {accuracy_score(all_labels, all_preds) * 100:.2f}%\n")
print("Classification Report:")
print(classification_report(all_labels, all_preds, target_names=['Real (0)', 'Fake (1)']))
print("Confusion Matrix:")
print(confusion_matrix(all_labels, all_preds))
# Out:
# Combining Data...
# Properly Stacking GloVe Vectors...
# Train GloVe Shape: (17061, 5, 100)
# Using device: cuda
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-base
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.bias                    | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# pooler.dense.weight             | MISSING    |
# pooler.dense.bias               | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# ...

# %%
# ==========================================
# 7. SAVE THE MODEL
# ==========================================
print("\n--- Saving the Model ---")

# Define the file name
MODEL_PATH = "hybrid_4_fake_job_model.pth"

# Save the learned weights (state_dict)
torch.save(model.state_dict(), MODEL_PATH)

print(f"Model successfully saved to: {MODEL_PATH}")
print("Congratulations! Your Fake Job Detection model is fully trained and saved.")
# Out:
# --- Saving the Model ---
# Model successfully saved to: hybrid_4_fake_job_model.pth
# Congratulations! Your Fake Job Detection model is fully trained and saved.

# %%
import torch
print("CUDA Version PyTorch Sees:", torch.version.cuda)
# Out:
# CUDA Version PyTorch Sees: 12.1

# %%
pip uninstall torch torchvision torchaudio -y
# Out:
# Found existing installation: torch 2.10.0+cpu
# Uninstalling torch-2.10.0+cpu:
#   Successfully uninstalled torch-2.10.0+cpu
# Found existing installation: torchvision 0.25.0+cpu
# Uninstalling torchvision-0.25.0+cpu:
#   Successfully uninstalled torchvision-0.25.0+cpu
# Found existing installation: torchaudio 2.10.0+cpu
# Uninstalling torchaudio-2.10.0+cpu:
#   Successfully uninstalled torchaudio-2.10.0+cpu

# %%
#pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
import torch
print("CUDA Version PyTorch Sees:", torch.version.cuda)
# Out:
# CUDA Version PyTorch Sees: 12.1

# %%
# !nvidia-smi
# Out:
# Thu May  7 08:32:39 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   35C    P0             51W /  400W |       0MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
import joblib
from sklearn.preprocessing import RobustScaler


salary_scaler = RobustScaler()
train_salary_scaled = salary_scaler.fit_transform(X_train_fake_job[['min_salary', 'max_salary']])


joblib.dump(salary_scaler, 'salary_scaler.pkl')

print("salary_scaler.pkl saved successfuully!")
# Out:
# salary_scaler.pkl ഫയൽ വിജയകരമായി സേവ് ചെയ്തു!
